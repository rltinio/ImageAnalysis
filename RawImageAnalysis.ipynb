# %%
import numpy as np
import scipy as sp
import skimage as ski
import skimage.io as io
#from tifffile import imread, imwrite
import PIL
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading in Data

# %%
img_path = '/Users/raphaeltinio/Desktop/assessing model/training5.tif'

# %%
image = PIL.Image.open(img_path)

# %%
info_dict = {
    "Filename": image.filename.split('/')[1],
    "Image Size": image.size,
    "Image Height": image.height,
    "Image Width": image.width,
    "Image Format": image.format,
    "Image Mode": image.mode,
    "Image is Animated": getattr(image, "is_animated", False),
    "Frames in Image": getattr(image, "n_frames", 1),
}

print(info_dict)
# Out:
# {'Filename': 'Users', 'Image Size': (1024, 1024), 'Image Height': 1024, 'Image Width': 1024, 'Image Format': 'TIFF', 'Image Mode': 'P', 'Image is Animated': True, 'Frames in Image': 2}

# %%
img_path = '/Users/raphaeltinio/Desktop/assessing model/WGATesting.tif'
image = io.imread(img_path, plugin = 'tifffile')
image.shape
# Out:
# (87, 1024, 1024)

# %%
#fig, (ax1, ax2) = plt.subplots(1,2)

io.imshow(image[0])
# Out:
# Text(200, 200, 'hello')
